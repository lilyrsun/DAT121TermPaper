# %%
import statsmodels.api as sm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv(r"C:\Users\Lily Sun\Desktop\DAT 121\LifeExpectancyData-Python.csv")

# %% [markdown]
# # 1. Identify the dependent and independent variables

# %% [markdown]
# # 2. Collect your data

# %%
data.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
#  12  Polio                            2919 non-null   float64
#  13  Total expenditure                2712 non-null   float64
#  14  Diphtheria                       2919 non-null   float64
#  15   HIV/AIDS                        2938 non-null   float64
#  16  GDP                              2490 non-null   float64
#  17  Population                       2286 non-null   float64
#  18   thinness  1-19 years            2904 non-null   float64
#  19   thinness 5-9 years              2904 non-null   float64
#  20  Income composition of resources  2771 non-null   float64
#  21  Schooling                        2775 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 505.1+ KB

# %%
data.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# min       0.010000                0.000000     1.000000       0.000000
# 25%       0.877500                4.685343    77.000000       0.000000
# 50%       3.755000               64.912906    92.000000      17.000000
# 75%       7.702500              441.534144    97.000000     360.250000
# max      17.870000            19479.911610    99.000000  212183.000000
#
#               BMI   under-five deaths         Polio  Total expenditure  \
# count  2904.000000         2938.000000  2919.000000         2712.00000
# mean     38.321247           42.035739    82.550188            5.93819
# std      20.044034          160.445548    23.428046            2.49832
# min       1.000000            0.000000     3.000000            0.37000
# 25%      19.300000            0.000000    78.000000            4.26000
# 50%      43.500000            4.000000    93.000000            5.75500
# 75%      56.200000           28.000000    97.000000            7.49250
# max      87.300000         2500.000000    99.000000           17.60000
#
#        Diphtheria      HIV/AIDS            GDP    Population  \
# count  2919.000000  2938.000000    2490.000000  2.286000e+03
# mean     82.324084     1.742103    7483.158469  1.275338e+07
# std      23.716912     5.077785   14270.169342  6.101210e+07
# min       2.000000     0.100000       1.681350  3.400000e+01
# 25%      78.000000     0.100000     463.935626  1.957932e+05
# 50%      93.000000     0.100000    1766.947595  1.386542e+06
# 75%      97.000000     0.800000    5910.806335  7.420359e+06
# max      99.000000    50.600000  119172.741800  1.293859e+09
#
#         thinness  1-19 years   thinness 5-9 years  \
# count            2904.000000          2904.000000
# mean                4.839704             4.870317
# std                 4.420195             4.508882
# min                 0.100000             0.100000
# 25%                 1.600000             1.500000
# 50%                 3.300000             3.300000
# 75%                 7.200000             7.200000
# max                27.700000            28.600000
#
#        Income composition of resources    Schooling
# count                      2771.000000  2775.000000
# mean                          0.627551    11.992793
# std                           0.210904     3.358920
# min                           0.000000     0.000000
# 25%                           0.493000    10.100000
# 50%                           0.677000    12.300000
# 75%                           0.779000    14.300000
# max                           0.948000    20.700000

# %% [markdown]
# # 3. Using descriptive methods validate the integrity of the data.
# ### Identify missing values, inconsistent measurement, or other possible issues with the data. Scatter plots are helpful for identifying problems.

# %%
data.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
print(data.columns)
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
data_latest_year = data[data['Year'] == 2014]
data_latest_year.head()
# Out:
#                 Country  Year      Status  Life expectancy   Adult Mortality  \
# 1           Afghanistan  2014  Developing              59.9            271.0
# 17              Albania  2014  Developing              77.5              8.0
# 33              Algeria  2014  Developing              75.4             11.0
# 49               Angola  2014  Developing              51.7            348.0
# 65  Antigua and Barbuda  2014  Developing              76.2            131.0
#
#     infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 1              64     0.01               73.523582         62.0       492
# 17              0     4.51              428.749067         98.0         0
# 33             21     0.01               54.237318         95.0         0
# 49             67     8.33               23.965612         64.0     11699
# 65              0     8.56             2422.999774         99.0         0
#
#     ...  Polio  Total expenditure  Diphtheria    HIV/AIDS           GDP  \
# 1   ...   58.0               8.18         62.0        0.1    612.696514
# 17  ...   98.0               5.88         98.0        0.1   4575.763787
# 33  ...   95.0               7.21         95.0        0.1    547.851700
# 49  ...   68.0               3.31         64.0        2.0    479.312240
# 65  ...   96.0               5.54         99.0        0.2  12888.296670
#
#     Population   thinness  1-19 years   thinness 5-9 years  \
# 1     327582.0                   17.5                 17.5
# 17    288914.0                    1.2                  1.3
# 33  39113313.0                    6.0                  5.8
# 49   2692466.0                    8.5                  8.3
# 65         NaN                    3.3                  3.3
#
#     Income composition of resources  Schooling
# 1                             0.476       10.0
# 17                            0.761       14.2
# 33                            0.741       14.4
# 49                            0.527       11.4
# 65                            0.782       13.9
#
# [5 rows x 22 columns]

# %%
data_latest_year.shape
# Out:
# (183, 22)

# %%
data_latest_year.isnull().sum()
# Out:
# Country                             0
# Year                                0
# Status                              0
# Life expectancy                     0
# Adult Mortality                     0
# infant deaths                       0
# Alcohol                             1
# percentage expenditure              0
# Hepatitis B                        10
# Measles                             0
#  BMI                                2
# under-five deaths                   0
# Polio                               0
# Total expenditure                   2
# Diphtheria                          0
#  HIV/AIDS                           0
# GDP                                28
# Population                         41
#  thinness  1-19 years               2
#  thinness 5-9 years                 2
# Income composition of resources    10
# Schooling                          10
# dtype: int64

# %%
data_latest_year = data_latest_year.dropna()

# %%
print(data_latest_year.isnull().sum())
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
print(data_latest_year.shape)
# Out:
# (131, 22)

# %% [markdown]
# # 4. Consider various functional forms.
# ### There are a number of factors to consider here

# %%
data_latest_year.hist(figsize=(20, 15))
plt.show()

# %%
data_latest_year.columns = data_latest_year.columns.str.strip()  # Remove leading/trailing spaces
data_latest_year.columns = data_latest_year.columns.str.replace(" ", "_").str.lower()  # Replace spaces with underscores and lowercase
print(data_latest_year.columns)
# Out:
# Index(['country', 'year', 'status', 'life_expectancy', 'adult_mortality',
#        'infant_deaths', 'alcohol', 'percentage_expenditure', 'hepatitis_b',
#        'measles', 'bmi', 'under-five_deaths', 'polio', 'total_expenditure',
#        'diphtheria', 'hiv/aids', 'gdp', 'population', 'thinness__1-19_years',
#        'thinness_5-9_years', 'income_composition_of_resources', 'schooling'],
#       dtype='object')

# %% [markdown]
# ### Using scatter plots and simple linear regression models look for patterns in the data.

# %%
dependent_var = 'life_expectancy'
independent_vars = [col for col in data_latest_year.columns if col != dependent_var and col != 'country' and col != 'status' and col != 'year']

# Determine number of subplots (rows and columns)
n_vars = len(independent_vars)
n_cols = 3  # Choose the number of columns
n_rows = -(-n_vars // n_cols)  # Ceiling division to determine rows

# Create subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 5 * n_rows))

# Flatten axes for easier indexing
axes = axes.flatten()

# Plot scatterplots with trendlines
for i, var in enumerate(independent_vars):
    # Scatter plot
    axes[i].scatter(data_latest_year[var], data_latest_year[dependent_var], alpha=0.7, label='Data')
    
    # Compute the trendline
    x = data_latest_year[var]
    y = data_latest_year[dependent_var]
    coefficients = np.polyfit(x, y, 1)  # Linear fit (degree=1)
    trendline = np.poly1d(coefficients)

    # Extract slope and intercept
    slope, intercept = coefficients
    equation = f"y = {slope:.2f}x + {intercept:.2f}"
    
    # Plot the trendline
    axes[i].plot(x, trendline(x), color='red', label='Trendline')

    # Add equation of the trendline to the plot
    # Position the equation based on the data range
    x_pos = x.min() + (x.max() - x.min()) * 0.1
    y_pos = y.min() + (y.max() - y.min()) * 0.1
    axes[i].text(x_pos, y_pos, equation, color='red', fontsize=12)
    
    # Add labels and title
    axes[i].set_title(f"{var} vs {dependent_var}")
    axes[i].set_xlabel(var)
    axes[i].set_ylabel(dependent_var)
    axes[i].legend()

# Remove unused subplots if any
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# Adjust layout
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 15))
corr = data_latest_year.drop(columns=['year']).corr()
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()
# Out:
# C:\Users\Lily Sun\AppData\Local\Temp\ipykernel_25108\2620459381.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data_latest_year.drop(columns=['year']).corr()

# %% [markdown]
# ### Descriptive Statistics Prior to Adjusting for Skewness

# %%
data_latest_year.describe()
# Out:
#          year  life_expectancy  adult_mortality  infant_deaths     alcohol  \
# count   131.0       131.000000       131.000000     131.000000  131.000000
# mean   2014.0        70.519847       160.374046      28.564885    3.060916
# std       0.0         8.605226       110.142379     100.095424    4.090299
# min    2014.0        48.100000         2.000000       0.000000    0.010000
# 25%    2014.0        64.650000        74.500000       0.000000    0.010000
# 50%    2014.0        72.000000       144.000000       3.000000    0.010000
# 75%    2014.0        75.800000       225.000000      20.000000    6.305000
# max    2014.0        89.000000       522.000000     957.000000   15.190000
#
#        percentage_expenditure  hepatitis_b       measles         bmi  \
# count              131.000000   131.000000    131.000000  131.000000
# mean               850.874114    81.709924   2042.862595   40.475573
# std               2071.444348    23.764061   9842.341166   20.733667
# min                  0.442802     2.000000      0.000000    2.000000
# 25%                 48.311426    78.000000      0.000000   22.850000
# 50%                198.734350    91.000000     10.000000   45.900000
# 75%                718.323619    96.000000    289.500000   59.450000
# max              16255.161980    99.000000  79563.000000   77.100000
#
#        under-five_deaths       polio  total_expenditure  diphtheria  \
# count         131.000000  131.000000         131.000000  131.000000
# mean           38.236641   83.496183           6.106718   83.885496
# std           131.293086   20.966411           2.533227   21.839851
# min             0.000000    8.000000           1.210000    2.000000
# 25%             1.000000   78.000000           4.485000   80.000000
# 50%             3.000000   92.000000           5.820000   92.000000
# 75%            25.500000   97.000000           7.630000   97.000000
# max          1200.000000   99.000000          13.730000   99.000000
#
#          hiv/aids            gdp    population  thinness__1-19_years  \
# count  131.000000     131.000000  1.310000e+02            131.000000
# mean     0.809924    7256.846908  2.226910e+07              4.648092
# std      1.562043   14741.395735  1.166999e+08              4.420587
# min      0.100000      12.277330  4.100000e+01              0.100000
# 25%      0.100000     554.924544  2.876005e+05              1.500000
# 50%      0.100000    2522.796800  1.562974e+06              3.300000
# 75%      0.500000    7438.053832  8.059265e+06              6.650000
# max      9.400000  119172.741800  1.293859e+09             26.800000
#
#        thinness_5-9_years  income_composition_of_resources   schooling
# count          131.000000                       131.000000  131.000000
# mean             4.886260                         0.669687   12.676336
# std              4.543478                         0.151314    2.750380
# min              0.100000                         0.345000    5.300000
# 25%              1.550000                         0.544000   10.750000
# 50%              3.500000                         0.697000   12.700000
# 75%              6.800000                         0.779000   14.700000
# max             27.400000                         0.936000   20.400000

# %% [markdown]
# ### Adjust for Skewness

# %%
data_latest_year.skew()
# Out:
# C:\Users\Lily Sun\AppData\Local\Temp\ipykernel_25108\178102410.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_latest_year.skew()
# year                                0.000000
# life_expectancy                    -0.224346
# adult_mortality                     0.755771
# infant_deaths                       7.310781
# alcohol                             1.090225
# percentage_expenditure              4.919264
# hepatitis_b                        -2.129445
# measles                             6.400972
# bmi                                -0.225871
# under-five_deaths                   6.956292
# polio                              -2.181121
# total_expenditure                   0.317158
# diphtheria                         -2.403467
# hiv/aids                            2.954731
# gdp                                 4.622799
# population                         10.197060
# thinness__1-19_years                2.036581
# thinness_5-9_years                  1.927627
# income_composition_of_resources    -0.241757
# schooling                          -0.035990
# dtype: float64

# %% [markdown]
# A value > 0.5 (positively skewed) or < -0.5 (negatively skewed) may indicate significant skewness.
#
# Highly skewed variables (positive skew):
# positively_skewed_vars = [
#     'infant_deaths', 'percentage_expenditure', 'measles',
#     'under-five_deaths', 'hiv/aids', 'gdp', 'population',
# ]
#
# negatively_skewed_vars = ['Hepatitis B', 'Polio', 'Diphtheria']

# %%
data_latest_year.columns = data_latest_year.columns.str.strip()  # Remove leading/trailing spaces
data_latest_year.columns = data_latest_year.columns.str.replace(" ", "_").str.lower()  # Replace spaces with underscores and lowercase
print(data_latest_year.columns)
# Out:
# Index(['country', 'year', 'status', 'life_expectancy', 'adult_mortality',
#        'infant_deaths', 'alcohol', 'percentage_expenditure', 'hepatitis_b',
#        'measles', 'bmi', 'under-five_deaths', 'polio', 'total_expenditure',
#        'diphtheria', 'hiv/aids', 'gdp', 'population', 'thinness__1-19_years',
#        'thinness_5-9_years', 'income_composition_of_resources', 'schooling'],
#       dtype='object')

# %%
positively_skewed_vars = [
    'infant_deaths', 'percentage_expenditure', 'measles', 
    'under-five_deaths', 'hiv/aids', 'gdp', 'population'
]

for var in positively_skewed_vars:
    data_latest_year[var] = np.log1p(data_latest_year[var])

# %%
# Apply reverse-log transformation to negatively skewed variables
negatively_skewed_vars = ['hepatitis_b', 'polio', 'diphtheria']

for var in negatively_skewed_vars:
    data_latest_year[var] = np.log1p(data_latest_year[var].max() - data_latest_year[var])

# %%
data_latest_year.describe()
# Out:
#          year  life_expectancy  adult_mortality  infant_deaths     alcohol  \
# count   131.0       131.000000       131.000000     131.000000  131.000000
# mean   2014.0        70.519847       160.374046       1.796202    3.060916
# std       0.0         8.605226       110.142379       1.622355    4.090299
# min    2014.0        48.100000         2.000000       0.000000    0.010000
# 25%    2014.0        64.650000        74.500000       0.000000    0.010000
# 50%    2014.0        72.000000       144.000000       1.386294    0.010000
# 75%    2014.0        75.800000       225.000000       3.043387    6.305000
# max    2014.0        89.000000       522.000000       6.864848   15.190000
#
#        percentage_expenditure  hepatitis_b     measles         bmi  \
# count              131.000000   131.000000  131.000000  131.000000
# mean                 5.124371     2.201642    2.966208   40.475573
# std                  1.989415     1.223194    3.163990   20.733667
# min                  0.366587     0.000000    0.000000    2.000000
# 25%                  3.897526     1.386294    0.000000   22.850000
# 50%                  5.296988     2.197225    2.397895   45.900000
# 75%                  6.578302     3.091042    5.671602   59.450000
# max                  9.696227     4.584967   11.284317   77.100000
#
#        under-five_deaths       polio  total_expenditure  diphtheria  \
# count         131.000000  131.000000         131.000000  131.000000
# mean            1.958359    2.089169           6.106718    2.047443
# std             1.723045    1.256008           2.533227    1.248268
# min             0.000000    0.000000           1.210000    0.000000
# 25%             0.693147    1.098612           4.485000    1.098612
# 50%             1.386294    2.079442           5.820000    2.079442
# 75%             3.275540    3.091042           7.630000    2.994481
# max             7.090910    4.521789          13.730000    4.584967
#
#          hiv/aids         gdp  population  thinness__1-19_years  \
# count  131.000000  131.000000  131.000000            131.000000
# mean     0.399527    7.553216   14.107434              4.648092
# std      0.534575    1.865930    2.655054              4.420587
# min      0.095310    2.586058    3.737670              0.100000
# 25%      0.095310    6.320552   12.569321              1.500000
# 50%      0.095310    7.833520   14.262102              3.300000
# 75%      0.405465    8.914467   15.901624              6.650000
# max      2.341806   11.688338   20.980895             26.800000
#
#        thinness_5-9_years  income_composition_of_resources   schooling
# count          131.000000                       131.000000  131.000000
# mean             4.886260                         0.669687   12.676336
# std              4.543478                         0.151314    2.750380
# min              0.100000                         0.345000    5.300000
# 25%              1.550000                         0.544000   10.750000
# 50%              3.500000                         0.697000   12.700000
# 75%              6.800000                         0.779000   14.700000
# max             27.400000                         0.936000   20.400000

# %%
for column in data_latest_year.select_dtypes(include=[np.number]).columns:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=data_latest_year[column])
    plt.title(f"Boxplot of {column}")
    plt.show()

# %% [markdown]
# # 5. Develop the full model, including all independent variables.

# %%
X = data_latest_year.drop(columns=['life_expectancy', 'country', 'year'])
y = data_latest_year['life_expectancy']

# %%
X = pd.get_dummies(X, drop_first=True)

# %%
X = sm.add_constant(X)
mlr_model = sm.OLS(y, X).fit()
print(mlr_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.900
# Model:                            OLS   Adj. R-squared:                  0.883
# Method:                 Least Squares   F-statistic:                     52.69
# Date:                Thu, 05 Dec 2024   Prob (F-statistic):           1.33e-46
# Time:                        21:50:27   Log-Likelihood:                -316.40
# No. Observations:                 131   AIC:                             672.8
# Df Residuals:                     111   BIC:                             730.3
# Df Model:                          19
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              56.9582      4.029     14.136      0.000      48.974      64.943
# adult_mortality                    -0.0183      0.004     -4.689      0.000      -0.026      -0.011
# infant_deaths                      -2.1289      2.107     -1.010      0.314      -6.304       2.046
# alcohol                             0.0207      0.092      0.225      0.822      -0.161       0.202
# percentage_expenditure              1.5097      0.436      3.463      0.001       0.646       2.373
# hepatitis_b                         0.2761      0.513      0.538      0.591      -0.740       1.292
# measles                            -0.1477      0.114     -1.299      0.197      -0.373       0.078
# bmi                                -0.0120      0.018     -0.656      0.513      -0.048       0.024
# under-five_deaths                   2.4569      2.039      1.205      0.231      -1.584       6.498
# polio                              -0.1096      0.631     -0.174      0.862      -1.360       1.141
# total_expenditure                   0.2031      0.118      1.717      0.089      -0.031       0.438
# diphtheria                         -0.3239      0.775     -0.418      0.677      -1.860       1.213
# hiv/aids                           -3.7273      0.734     -5.081      0.000      -5.181      -2.274
# gdp                                -1.3476      0.458     -2.941      0.004      -2.255      -0.440
# population                         -0.0644      0.125     -0.513      0.609      -0.313       0.184
# thinness__1-19_years               -0.0412      0.183     -0.225      0.822      -0.404       0.321
# thinness_5-9_years                 -0.0281      0.186     -0.151      0.880      -0.397       0.341
# income_composition_of_resources    32.8452      6.424      5.113      0.000      20.115      45.575
# schooling                          -0.0428      0.258     -0.166      0.868      -0.553       0.468
# status_Developing                  -1.0242      0.963     -1.063      0.290      -2.933       0.885
# ==============================================================================
# Omnibus:                        2.985   Durbin-Watson:                   2.106
# Prob(Omnibus):                  0.225   Jarque-Bera (JB):                2.952
# Skew:                           0.108   Prob(JB):                        0.229
# Kurtosis:                       3.703   Cond. No.                     5.34e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.34e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Significant variables include adult_mortality and percentage_expenditure.

# %%
# confirm calculation with snir

rss = mlr_model.ssr
df_residuals = mlr_model.df_resid
rse = np.sqrt(rss / df_residuals)
print(f"Standard Error of the Model (RSE): {rse}")
# Out:
# Standard Error of the Model (RSE): 2.942139375327847

# %% [markdown]
# # 6. Evaluate the standard regression assumptions, by evaluating residuals

# %% [markdown]
# ### Residual Analysis

# %% [markdown]
# ##### Residuals vs. Fitted Values (Linearity and Homoscedasticity)

# %%
sns.residplot(x=mlr_model.fittedvalues, y=mlr_model.resid, lowess=True, line_kws={"color": "red"})
plt.title("Residuals vs. Fitted Values")
plt.xlabel("Fitted Values")
plt.ylabel("Residuals")
plt.show()

# %% [markdown]
# - The residuals are approximately centered around zero, indicating a reasonable fit.
# - However, the slight curvature suggests some non-linearity in the relationship between predictors and the dependent variable.
# - Conclusion: The model largely meets the linearity assumption, but a more flexible model (e.g., polynomial terms or interaction effects) could improve fit.

# %% [markdown]
# ##### Normality of Residuals (Q-Q Plot)

# %%
sm.qqplot(mlr_model.resid, line='45')
plt.title("Q-Q Plot of Residuals")
plt.show()

# %% [markdown]
# - Ask Professor Snir what to do about this

# %% [markdown]
# ### Calculate Studentized Residuals, Leverage, and Cook’s D.
# ##### Perhaps look at the histogram of the Studentized Residuals.

# %%
sns.histplot(mlr_model.resid, kde=True)
plt.title("Histogram of Residuals")
plt.show()

# %% [markdown]
# **EDIT WORDING ACCORDING TO LECTURE NOTES**
# - The residual distribution is approximately symmetric with a slight central peak.
# - The accompanying kernel density estimation (KDE) further supports normality.

# %% [markdown]
# ### Test for Homoscedasticity

# %% [markdown]
# ##### Breusch-Pagan Test

# %%
from statsmodels.stats.diagnostic import het_breuschpagan

bp_test = het_breuschpagan(mlr_model.resid, mlr_model.model.exog)
print(f"Breusch-Pagan Test Statistic: {bp_test[0]}, p-value: {bp_test[1]}")

if bp_test[1] < 0.05:
    print("Evidence of heteroscedasticity. Consider transformations.")
else:
    print("No evidence of heteroscedasticity.")
# Out:
# Breusch-Pagan Test Statistic: 19.451632750687562, p-value: 0.4282271249175896
# No evidence of heteroscedasticity.

# %% [markdown]
# - Test statistic: 16.97, p-value = 0.257.
# - Conclusion: There is no evidence of heteroscedasticity, confirming that the variance of residuals is constant across fitted values.

# %% [markdown]
# ## Identify Influential Points

# %% [markdown]
# ### Studentized Residuals

# %%
influence = mlr_model.get_influence()
studentized_residuals = influence.resid_studentized_internal
sns.histplot(studentized_residuals, kde=True)
plt.title("Histogram of Studentized Residuals")
plt.show()

# %%
from statsmodels.stats.outliers_influence import OLSInfluence

# Calculate studentized residuals
influence = OLSInfluence(mlr_model)
studentized_residuals = influence.resid_studentized_internal

# Flag outliers
outliers = studentized_residuals[abs(studentized_residuals) > 2].index
extreme_outliers = studentized_residuals[abs(studentized_residuals) > 3].index

print("Potential Outliers (|residuals| > 2):", outliers.tolist())
print("Extreme Outliers (|residuals| > 3):", extreme_outliers.tolist())
# Out:
# Potential Outliers (|residuals| > 2): [49, 241, 513, 835, 1027, 2056, 2298]
# Extreme Outliers (|residuals| > 3): [2298]

# %% [markdown]
# ### Leverage

# %%
# Calculate leverage
leverage = influence.hat_matrix_diag
k = mlr_model.df_model  # Number of predictors
n = mlr_model.nobs  # Number of observations
leverage_threshold = 3 * (k + 1) / n

# Identify high-leverage points
high_leverage_points = (leverage > leverage_threshold).nonzero()[0]

print("High-Leverage Points (leverage > {:.3f}):".format(leverage_threshold), high_leverage_points)
# Out:
# High-Leverage Points (leverage > 0.458): [76]

# %%
sns.scatterplot(x=leverage, y=studentized_residuals)
plt.axhline(y=2, color='red', linestyle='--', label="Residual Threshold ±2")
plt.axhline(y=-2, color='red', linestyle='--')
plt.axvline(x=leverage_threshold, color='blue', linestyle='--', label="Leverage Threshold")
plt.title("Leverage vs. Studentized Residuals")
plt.legend()
plt.show()

# %% [markdown]
# Have studentized resid not as func of leverage --> stud resid as a function of each independent variable --> 12 subplots

# %% [markdown]
# ### Cook's D

# %%
# Calculate Cook's Distance
cooks_d = influence.cooks_distance[0]
cooks_threshold = 4 / n

# Identify influential points
influential_points = cooks_d[cooks_d > cooks_threshold].index

print("Influential Points (Cook's Distance > {:.3f}):".format(cooks_threshold), influential_points.tolist())
# Out:
# Influential Points (Cook's Distance > 0.031): [49, 241, 513, 754, 835, 1027, 1107, 1894, 2056, 2298, 2731]

# %%
sns.scatterplot(x=range(len(cooks_d)), y=cooks_d)
plt.axhline(y=cooks_threshold, color='red', linestyle='--', label="Cook's Threshold")
plt.title("Cook's Distance")
plt.legend()
plt.show()

# %% [markdown]
# - Threshold: 0.031.
# - Only a few points exceed the threshold, indicating limited influence of individual observations on the model.
# - Conclusion: The model is relatively robust, but sensitivity testing (removing high-influence points) is recommended.

# %%
# Remove influential points
X_cleaned = X.drop(index=influential_points)
y_cleaned = y.drop(index=influential_points)

# %%
# Define dependent and independent variables
dependent_var = 'life_expectancy'
independent_vars = [col for col in X_cleaned.columns if col != 'const']  # Remove 'const' since it's added for regression

# Determine number of subplots (rows and columns)
n_vars = len(independent_vars)
n_cols = 3  # Choose the number of columns
n_rows = -(-n_vars // n_cols)  # Ceiling division to determine rows

# Create subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 5 * n_rows))

# Flatten axes for easier indexing
axes = axes.flatten()

# Plot scatterplots with trendlines
for i, var in enumerate(independent_vars):
    # Scatter plot with cleaned data
    axes[i].scatter(X_cleaned[var], y_cleaned, alpha=0.7, label='Data')
    
    # Compute the trendline with cleaned data
    x = X_cleaned[var]
    y = y_cleaned
    coefficients = np.polyfit(x, y, 1)  # Linear fit (degree=1)
    trendline = np.poly1d(coefficients)

    # Extract slope and intercept
    slope, intercept = coefficients
    equation = f"y = {slope:.2f}x + {intercept:.2f}"
    
    # Plot the trendline
    axes[i].plot(x, trendline(x), color='red', label='Trendline')

    # Add equation of the trendline to the plot
    # Position the equation based on the data range
    x_pos = x.min() + (x.max() - x.min()) * 0.1
    y_pos = y.min() + (y.max() - y.min()) * 0.1
    axes[i].text(x_pos, y_pos, equation, color='red', fontsize=12)
    
    # Add labels and title
    axes[i].set_title(f"{var} vs {dependent_var}")
    axes[i].set_xlabel(var)
    axes[i].set_ylabel(dependent_var)
    axes[i].legend()

# Remove unused subplots if any
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Rerun regression
X_cleaned = sm.add_constant(X_cleaned)
mlr_model_cleaned = sm.OLS(y_cleaned, X_cleaned).fit()

print(mlr_model_cleaned.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     72.95
# Date:                Thu, 05 Dec 2024   Prob (F-statistic):           6.95e-50
# Time:                        21:50:39   Log-Likelihood:                -252.63
# No. Observations:                 120   AIC:                             545.3
# Df Residuals:                     100   BIC:                             601.0
# Df Model:                          19
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              52.0896      3.246     16.049      0.000      45.650      58.529
# adult_mortality                    -0.0155      0.003     -4.676      0.000      -0.022      -0.009
# infant_deaths                      -2.5075      1.952     -1.284      0.202      -6.381       1.366
# alcohol                            -0.0429      0.073     -0.591      0.556      -0.187       0.101
# percentage_expenditure              1.1217      0.364      3.083      0.003       0.400       1.844
# hepatitis_b                         0.1044      0.395      0.264      0.792      -0.679       0.888
# measles                            -0.0682      0.087     -0.784      0.435      -0.241       0.104
# bmi                                 0.0004      0.015      0.028      0.978      -0.030       0.031
# under-five_deaths                   2.7630      1.898      1.456      0.149      -1.002       6.528
# polio                               0.1355      0.474      0.286      0.776      -0.805       1.076
# total_expenditure                   0.3890      0.099      3.915      0.000       0.192       0.586
# diphtheria                         -0.2350      0.590     -0.398      0.691      -1.406       0.936
# hiv/aids                           -3.5662      0.643     -5.548      0.000      -4.841      -2.291
# gdp                                -1.1537      0.360     -3.201      0.002      -1.869      -0.439
# population                         -0.0227      0.098     -0.231      0.818      -0.217       0.172
# thinness__1-19_years               -0.1586      0.160     -0.992      0.324      -0.476       0.159
# thinness_5-9_years                  0.1303      0.160      0.814      0.417      -0.187       0.448
# income_composition_of_resources    38.3932      5.172      7.423      0.000      28.132      48.654
# schooling                          -0.2137      0.214     -1.001      0.319      -0.637       0.210
# status_Developing                  -0.3878      0.766     -0.507      0.614      -1.907       1.131
# ==============================================================================
# Omnibus:                        0.825   Durbin-Watson:                   2.166
# Prob(Omnibus):                  0.662   Jarque-Bera (JB):                0.880
# Skew:                          -0.069   Prob(JB):                        0.644
# Kurtosis:                       2.604   Cond. No.                     5.34e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.34e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# confirm calculation with snir

rss = mlr_model_cleaned.ssr
df_residuals = mlr_model_cleaned.df_resid
rse = np.sqrt(rss / df_residuals)
print(f"Standard Error of the Model (RSE): {rse}")
# Out:
# Standard Error of the Model (RSE): 2.175986854023683

# %% [markdown]
# ### Address Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Calculate VIF for each feature
vif_data = pd.DataFrame()
vif_data["feature"] = X_cleaned.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print(vif_data)
# Out:
#                             feature         VIF
# 0                             const  245.700358
# 1                   adult_mortality    2.769833
# 2                     infant_deaths  175.484209
# 3                           alcohol    2.113287
# 4            percentage_expenditure   11.293472
# 5                       hepatitis_b    5.908935
# 6                           measles    1.943411
# 7                               bmi    2.148614
# 8                 under-five_deaths  185.448681
# 9                             polio    9.435932
# 10                total_expenditure    1.349164
# 11                       diphtheria   14.069889
# 12                         hiv/aids    2.309286
# 13                              gdp   10.975640
# 14                       population    1.665697
# 15             thinness__1-19_years    9.827429
# 16               thinness_5-9_years   10.766275
# 17  income_composition_of_resources   14.191629
# 18                        schooling    7.537215
# 19                status_Developing    1.741718

# %% [markdown]
# From your output, the following variables have high VIF (>10):
#
# - infant_deaths (164.28)
# - under-five_deaths (175.43)
# - percentage_expenditure (10.89)
# - diphtheria (14.05)
# - thinness__1-19_years (9.73)
# - thinness_5-9_years (10.56)
# - income_composition_of_resources (12.92)

# %%
# Correlation matrix
plt.figure(figsize=(20,15))
corr_matrix = X_cleaned.corr()
print(corr_matrix)
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.show()
# Out:
#                                  const  adult_mortality  infant_deaths  \
# const                              NaN              NaN            NaN
# adult_mortality                    NaN         1.000000       0.409718
# infant_deaths                      NaN         0.409718       1.000000
# alcohol                            NaN        -0.260278      -0.288335
# percentage_expenditure             NaN        -0.271671      -0.492343
# hepatitis_b                        NaN         0.260304       0.225780
# measles                            NaN         0.113159       0.558095
# bmi                                NaN        -0.420620      -0.445673
# under-five_deaths                  NaN         0.437333       0.996498
# polio                              NaN         0.411230       0.350404
# total_expenditure                  NaN        -0.159686      -0.226993
# diphtheria                         NaN         0.347048       0.304059
# hiv/aids                           NaN         0.719738       0.308646
# gdp                                NaN        -0.325200      -0.405221
# population                         NaN         0.196635       0.488619
# thinness__1-19_years               NaN         0.251276       0.498145
# thinness_5-9_years                 NaN         0.254486       0.505566
# income_composition_of_resources    NaN        -0.637728      -0.574570
# schooling                          NaN        -0.544656      -0.566666
# status_Developing                  NaN         0.309464       0.352712
#
#                                   alcohol  percentage_expenditure  \
# const                                 NaN                     NaN
# adult_mortality                 -0.260278               -0.271671
# infant_deaths                   -0.288335               -0.492343
# alcohol                          1.000000                0.492891
# percentage_expenditure           0.492891                1.000000
# hepatitis_b                     -0.077514               -0.076539
# measles                         -0.012013               -0.234882
# bmi                              0.404017                0.351053
# under-five_deaths               -0.306910               -0.504217
# polio                           -0.215403               -0.170381
# total_expenditure                0.319812                0.362972
# diphtheria                      -0.222919               -0.182995
# hiv/aids                        -0.262985               -0.176305
# gdp                              0.486413                0.933419
# population                       0.170193               -0.093911
# thinness__1-19_years            -0.359123               -0.344971
# thinness_5-9_years              -0.360585               -0.386325
# income_composition_of_resources  0.608590                0.630263
# schooling                        0.574338                0.583978
# status_Developing               -0.476850               -0.310864
#
#                                  hepatitis_b   measles       bmi  \
# const                                    NaN       NaN       NaN
# adult_mortality                     0.260304  0.113159 -0.420620
# infant_deaths                       0.225780  0.558095 -0.445673
# alcohol                            -0.077514 -0.012013  0.404017
# percentage_expenditure             -0.076539 -0.234882  0.351053
# hepatitis_b                         1.000000  0.188631 -0.012107
# measles                             0.188631  1.000000 -0.190293
# bmi                                -0.012107 -0.190293  1.000000
# under-five_deaths                   0.229395  0.547063 -0.469062
# polio                               0.802389  0.179988 -0.116541
# total_expenditure                  -0.081892 -0.157720  0.196283
# diphtheria                          0.868579  0.188962 -0.090811
# hiv/aids                            0.201669  0.020139 -0.401269
# gdp                                -0.082108 -0.152959  0.344037
# population                          0.120878  0.208314 -0.143038
# thinness__1-19_years               -0.051797  0.309939 -0.559397
# thinness_5-9_years                 -0.015111  0.331739 -0.594682
# income_composition_of_resources    -0.272080 -0.133377  0.651748
# schooling                          -0.314258 -0.138644  0.594809
# status_Developing                   0.063190  0.027297 -0.287607
#
#                                  under-five_deaths     polio  \
# const                                          NaN       NaN
# adult_mortality                           0.437333  0.411230
# infant_deaths                             0.996498  0.350404
# alcohol                                  -0.306910 -0.215403
# percentage_expenditure                   -0.504217 -0.170381
# hepatitis_b                               0.229395  0.802389
# measles                                   0.547063  0.179988
# bmi                                      -0.469062 -0.116541
# under-five_deaths                         1.000000  0.359979
# polio                                     0.359979  1.000000
# total_expenditure                        -0.230454 -0.237763
# diphtheria                                0.311271  0.925626
# hiv/aids                                  0.345630  0.302165
# gdp                                      -0.422177 -0.150548
# population                                0.483863  0.170427
# thinness__1-19_years                      0.510163  0.052547
# thinness_5-9_years                        0.514081  0.084144
# income_composition_of_resources          -0.613044 -0.446968
# schooling                                -0.597366 -0.415699
# status_Developing                         0.362831  0.246872
#
#                                  total_expenditure  diphtheria  hiv/aids  \
# const                                          NaN         NaN       NaN
# adult_mortality                          -0.159686    0.347048  0.719738
# infant_deaths                            -0.226993    0.304059  0.308646
# alcohol                                   0.319812   -0.222919 -0.262985
# percentage_expenditure                    0.362972   -0.182995 -0.176305
# hepatitis_b                              -0.081892    0.868579  0.201669
# measles                                  -0.157720    0.188962  0.020139
# bmi                                       0.196283   -0.090811 -0.401269
# under-five_deaths                        -0.230454    0.311271  0.345630
# polio                                    -0.237763    0.925626  0.302165
# total_expenditure                         1.000000   -0.193438 -0.052560
# diphtheria                               -0.193438    1.000000  0.240741
# hiv/aids                                 -0.052560    0.240741  1.000000
# gdp                                       0.262556   -0.160522 -0.207009
# population                               -0.103266    0.108051  0.150787
# thinness__1-19_years                     -0.222681    0.034272  0.181456
# thinness_5-9_years                       -0.260417    0.072554  0.147945
# income_composition_of_resources           0.273585   -0.432531 -0.550601
# schooling                                 0.286802   -0.419763 -0.429784
# status_Developing                        -0.313110    0.261305  0.216875
#
#                                       gdp  population  thinness__1-19_years  \
# const                                 NaN         NaN                   NaN
# adult_mortality                 -0.325200    0.196635              0.251276
# infant_deaths                   -0.405221    0.488619              0.498145
# alcohol                          0.486413    0.170193             -0.359123
# percentage_expenditure           0.933419   -0.093911             -0.344971
# hepatitis_b                     -0.082108    0.120878             -0.051797
# measles                         -0.152959    0.208314              0.309939
# bmi                              0.344037   -0.143038             -0.559397
# under-five_deaths               -0.422177    0.483863              0.510163
# polio                           -0.150548    0.170427              0.052547
# total_expenditure                0.262556   -0.103266             -0.222681
# diphtheria                      -0.160522    0.108051              0.034272
# hiv/aids                        -0.207009    0.150787              0.181456
# gdp                              1.000000   -0.070341             -0.333311
# population                      -0.070341    1.000000              0.143474
# thinness__1-19_years            -0.333311    0.143474              1.000000
# thinness_5-9_years              -0.346065    0.118014              0.951498
# income_composition_of_resources  0.641493   -0.133796             -0.482311
# schooling                        0.582434   -0.072867             -0.474432
# status_Developing               -0.295450    0.002274              0.299247
#
#                                  thinness_5-9_years  \
# const                                           NaN
# adult_mortality                            0.254486
# infant_deaths                              0.505566
# alcohol                                   -0.360585
# percentage_expenditure                    -0.386325
# hepatitis_b                               -0.015111
# measles                                    0.331739
# bmi                                       -0.594682
# under-five_deaths                          0.514081
# polio                                      0.084144
# total_expenditure                         -0.260417
# diphtheria                                 0.072554
# hiv/aids                                   0.147945
# gdp                                       -0.346065
# population                                 0.118014
# thinness__1-19_years                       0.951498
# thinness_5-9_years                         1.000000
# income_composition_of_resources           -0.482967
# schooling                                 -0.476391
# status_Developing                          0.307571
#
#                                  income_composition_of_resources  schooling  \
# const                                                        NaN        NaN
# adult_mortality                                        -0.637728  -0.544656
# infant_deaths                                          -0.574570  -0.566666
# alcohol                                                 0.608590   0.574338
# percentage_expenditure                                  0.630263   0.583978
# hepatitis_b                                            -0.272080  -0.314258
# measles                                                -0.133377  -0.138644
# bmi                                                     0.651748   0.594809
# under-five_deaths                                      -0.613044  -0.597366
# polio                                                  -0.446968  -0.415699
# total_expenditure                                       0.273585   0.286802
# diphtheria                                             -0.432531  -0.419763
# hiv/aids                                               -0.550601  -0.429784
# gdp                                                     0.641493   0.582434
# population                                             -0.133796  -0.072867
# thinness__1-19_years                                   -0.482311  -0.474432
# thinness_5-9_years                                     -0.482967  -0.476391
# income_composition_of_resources                         1.000000   0.914132
# schooling                                               0.914132   1.000000
# status_Developing                                      -0.533991  -0.535407
#
#                                  status_Developing
# const                                          NaN
# adult_mortality                           0.309464
# infant_deaths                             0.352712
# alcohol                                  -0.476850
# percentage_expenditure                   -0.310864
# hepatitis_b                               0.063190
# measles                                   0.027297
# bmi                                      -0.287607
# under-five_deaths                         0.362831
# polio                                     0.246872
# total_expenditure                        -0.313110
# diphtheria                                0.261305
# hiv/aids                                  0.216875
# gdp                                      -0.295450
# population                                0.002274
# thinness__1-19_years                      0.299247
# thinness_5-9_years                        0.307571
# income_composition_of_resources          -0.533991
# schooling                                -0.535407
# status_Developing                         1.000000

# %% [markdown]
# #### In final paper, use analysis above to explain why SLR may be significant but MLR isn't

# %% [markdown]
# ##### What's next: finish variable selection, influence/leverage/whatever else points, outliers, residual analysis

# %% [markdown]
# # 7. Decide which variables to include in the MLR, based on the correlations and several MLR models

# %% [markdown]
# ##### Keep the following variables in the MLR:
# - Any variable that is statistically significant in the complete MLR, with all variables.
# - A variable that is statistically significant in the SLR with the dependent variable. It is sufficient to evaluate the correlation with the dependent variable, rxy.
# - A variable that is significant in a different MLR.
#     - This raises the question of how many models to develop. It is sufficient to develop all
# models with k-1 independent variables. There are k such models.
#     - For the House Prices example, this requires developing 4 models. In each model, remove
# one of the variables, and evaluate the model with the remaining 3 variables.

# %% [markdown]
# ##### Significant Predictors from the Complete MLR (outliers removed)
# - adult mortality: (p<0.001)
# - percentage_expenditure (p=0.002)
# - total_expenditure (p=0.003): Now significant after removing influential points.
# - hiv/aids (p<0.001)
# - gdp (p=0.003)
# - income_composition_of_resources (p<0.001)

# %% [markdown]
# Non-significant predictors
# - infant deaths
# - alcohol
# - hepatitis_b
# - measles
# - bmi
# - under-five_deaths
# - polio
# - diphtheria
# - population
# - thinness__1-19_years
# - thinness_5-9_years
# - schooling
# - status_Developing

# %% [markdown]
# ##### Start with Correlation Analysis:
#
# - Identify independent variables that are statistically significantly correlated with the dependent variable using scatter plots or correlation coefficients.
# - Include variables with significant correlation coefficients in the MLR model, even if they are not significant in some individual models​

# %% [markdown]
# As a rule of thumb, the correlation between 2 variables is statistically significant, at α = 0.05
# (reject 𝐻0), if the sample correlation is higher (in absolute value) than a certain threshold. The
# threshold depends on the sample size (n).
# - For n = 100, rxy above 0.2 (in absolute value) is sufficient to reject 𝐻0

# %%
# Recalculate & plot Correlation matrix
if isinstance(y, list):
    y = pd.Series(y, name="life_expectancy")

data_with_y = pd.concat([X_cleaned, y], axis=1)
data_without_const = data_with_y.drop(columns=["const"])

corr_matrix = data_without_const.corr()

plt.figure(figsize=(20,15))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# ##### Variables that are statistically significant in the SLR with the dependent variable (|rxy| above 0.2 for df >= 100):
# - adult mortality
# - infant deaths
# - alcohol
# - percentage_expenditure
# - hepatitis_b
# - bmi
# - under-five_deaths
# - polio
# - total_expenditure
# - diphtheria
# - hiv/aids
# - GDP
# - thinness__1-19_years
# - thinness_5-9_years
# - composition_of_resources
# - schooling
# - status_developing
#
# Insignificant variables (|rxy| < 0.2)
# - measles
# - population

# %% [markdown]
# ### Develop Multiple Models (k-1 models)

# %%
# List of variables to remove (exclude 'const' if it's in X_cleaned)
X_cleaned.columns
# Out:
# Index(['const', 'adult_mortality', 'infant_deaths', 'alcohol',
#        'percentage_expenditure', 'hepatitis_b', 'measles', 'bmi',
#        'under-five_deaths', 'polio', 'total_expenditure', 'diphtheria',
#        'hiv/aids', 'gdp', 'population', 'thinness__1-19_years',
#        'thinness_5-9_years', 'income_composition_of_resources', 'schooling',
#        'status_Developing'],
#       dtype='object')

# %%
# dropping const from variables to test k-1 with
variables_to_remove = X_cleaned.drop(columns = "const")

# ;oop through each variable to remove and fit model
for variable in variables_to_remove:
    
    X_reduced = X_cleaned.drop(columns=[variable])
    
    X_reduced = sm.add_constant(X_reduced)
    
    reduced_model = sm.OLS(y_cleaned, X_reduced).fit()
    
    print(f"Removed Variable: {variable}")
    print(reduced_model.summary())
    print("\n" + "="*80 + "\n")  # Separator for better readability
# Out:
# Removed Variable: adult_mortality
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.903
# Method:                 Least Squares   F-statistic:                     62.81
# Date:                Thu, 05 Dec 2024   Prob (F-statistic):           1.49e-46
# Time:                        22:00:18   Log-Likelihood:                -264.50
# No. Observations:                 120   AIC:                             567.0
# Df Residuals:                     101   BIC:                             620.0
# Df Model:                          18
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              46.6342      3.327     14.018      0.000      40.035      53.234
# infant_deaths                      -3.4461      2.133     -1.615      0.109      -7.678       0.786
# alcohol                            -0.0972      0.079     -1.234      0.220      -0.253       0.059
# percentage_expenditure              0.6989      0.387      1.805      0.074      -0.069       1.467
# hepatitis_b                         0.2407      0.433      0.557      0.579      -0.617       1.099
# measles                            -0.0919      0.095     -0.964      0.338      -0.281       0.097
# bmi                                -0.0036      0.017     -0.216      0.830      -0.037       0.030
# under-five_deaths                   3.6118      2.075      1.741      0.085      -0.504       7.728
# polio                              -0.1024      0.518     -0.198      0.844      -1.130       0.925
# total_expenditure                   0.4386      0.109      4.041      0.000       0.223       0.654
# diphtheria                         -0.1858      0.648     -0.287      0.775      -1.472       1.101
# hiv/aids                           -5.2452      0.586     -8.957      0.000      -6.407      -4.084
# gdp                                -0.7633      0.385     -1.982      0.050      -1.527       0.001
# population                         -0.0312      0.108     -0.289      0.773      -0.245       0.183
# thinness__1-19_years               -0.0482      0.174     -0.277      0.782      -0.393       0.297
# thinness_5-9_years                  0.0198      0.174      0.114      0.910      -0.325       0.365
# income_composition_of_resources    42.7731      5.587      7.656      0.000      31.690      53.856
# schooling                          -0.1905      0.235     -0.812      0.419      -0.656       0.275
# status_Developing                  -0.3971      0.841     -0.472      0.638      -2.065       1.271
# ==============================================================================
# Omnibus:                        2.177   Durbin-Watson:                   2.330
# Prob(Omnibus):                  0.337   Jarque-Bera (JB):                2.193
# Skew:                          -0.315   Prob(JB):                        0.334
# Kurtosis:                       2.793   Cond. No.                     1.40e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.4e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ================================================================================
#
# Removed Variable: infant_deaths
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.919
# Method:                 Least Squares   F-statistic:                     76.42
# Date:                Thu, 05 Dec 2024   Prob (F-statistic):           1.75e-50
# Time:                        22:00:18   Log-Likelihood:                -253.61
# No. Observations:                 120   AIC:                             545.2
# Df Residuals:                     101   BIC:                             598.2
# Df Model:                          18
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              53.6996      3.003     17.880      0.000      47.742      59.657
# adult_mortality                    -0.0160      0.003     -4.818      0.000      -0.023      -0.009
# alcohol                            -0.0352      0.073     -0.485      0.629      -0.179       0.109
# percentage_expenditure              1.1547      0.364      3.172      0.002       0.432       1.877
# hepatitis_b                         0.1130      0.396      0.285      0.776      -0.673       0.899
# measles                            -0.0660      0.087     -0.757      0.451      -0.239       0.107
# bmi                                 0.0018      0.015      0.116      0.908      -0.029       0.032
# under-five_deaths                   0.3460      0.243      1.424      0.157      -0.136       0.828
# polio                               0.1491      0.476      0.314      0.754      -0.794       1.092
# total_expenditure                   0.3819      0.100      3.837      0.000       0.184       0.579
# diphtheria                         -0.2933      0.591     -0.497      0.620      -1.465       0.878
# hiv/aids                           -3.3833      0.629     -5.381      0.000      -4.631      -2.136
# gdp                                -1.1613      0.362     -3.212      0.002      -1.879      -0.444
# population                         -0.0269      0.098     -0.273      0.785      -0.222       0.168
# thinness__1-19_years               -0.1445      0.160     -0.902      0.369      -0.462       0.173
# thinness_5-9_years                  0.1177      0.160      0.734      0.464      -0.200       0.436
# income_composition_of_resources    36.1302      4.878      7.407      0.000      26.453      45.807
# schooling                          -0.1994      0.214     -0.932      0.354      -0.624       0.225
# status_Developing                  -0.5013      0.763     -0.657      0.513      -2.015       1.012
# ==============================================================================
# Omnibus:                        0.202   Durbin-Watson:                   2.177
# Prob(Omnibus):                  0.904   Jarque-Bera (JB):                0.374
# Skew:                          -0.041   Prob(JB):                        0.829
# Kurtosis:                       2.739   Cond. No.                     4.83e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.83e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ================================================================================
#
# Removed Variable: alcohol
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     77.49
# Date:                Thu, 05 Dec 2024   Prob (F-statistic):           9.21e-51
# Time:                        22:00:18   Log-Likelihood:                -252.84
# No. Observations:                 120   AIC:                             543.7
# Df Residuals:                     101   BIC:                             596.6
# Df Model:                          18
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              52.6789      3.079     17.111      0.000      46.572      58.786
# adult_mortality                    -0.0159      0.003     -4.848      0.000      -0.022      -0.009
# infant_deaths                      -2.4122      1.940     -1.244      0.216      -6.260       1.435
# percentage_expenditure              1.1194      0.363      3.087      0.003       0.400       1.839
# hepatitis_b                         0.0975      0.393      0.248      0.805      -0.683       0.878
# measles                            -0.0736      0.086     -0.854      0.395      -0.245       0.097
# bmi                              -4.71e-05      0.015     -0.003      0.998      -0.031       0.030
# under-five_deaths                   2.6808      1.886      1.421      0.158      -1.061       6.423
# polio                               0.1371      0.473      0.290      0.772      -0.800       1.075
# total_expenditure                   0.3788      0.098      3.884      0.000       0.185       0.572
# diphtheria                         -0.2267      0.588     -0.385      0.701      -1.394       0.940
# hiv/aids                           -3.5322      0.638     -5.536      0.000      -4.798      -2.266
# gdp                                -1.1660      0.359     -3.251      0.002      -1.878      -0.454
# population                         -0.0401      0.093     -0.430      0.668      -0.225       0.145
# thinness__1-19_years               -0.1514      0.159     -0.952      0.343      -0.467       0.164
# thinness_5-9_years                  0.1258      0.159      0.789      0.432      -0.190       0.442
# income_composition_of_resources    37.8356      5.069      7.465      0.000      27.781      47.891
# schooling                          -0.2088      0.213     -0.982      0.329      -0.631       0.213
# status_Developing                  -0.3189      0.754     -0.423      0.673      -1.815       1.177
# ==============================================================================
# Omnibus:                        0.789   Durbin-Watson:                   2.170
# Prob(Omnibus):                  0.674   Jarque-Bera (JB):                0.870
# Skew:                          -0.087   Prob(JB):                        0.647
# Kurtosis:                       2.621   Cond. No.                     5.20e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.2e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ================================================================================
#
# Removed Variable: percentage_expenditure
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.926
# Model:                            OLS   Adj. R-squared:                  0.913
# Method:                 Least Squares   F-statistic:                     70.54
# Date:                Thu, 05 Dec 2024   Prob (F-statistic):           7.19e-49
# Time:                        22:00:19   Log-Likelihood:                -258.08
# No. Observations:                 120   AIC:                             554.2
# Df Residuals:                     101   BIC:                             607.1
# Df Model:                          18
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              48.3312      3.132     15.431      0.000      42.118      54.544
# adult_mortality                    -0.0130      0.003     -3.877      0.000      -0.020      -0.006
# infant_deaths                      -2.9324      2.028     -1.446      0.151      -6.955       1.091
# alcohol                            -0.0405      0.076     -0.536      0.593      -0.191       0.109
# hepatitis_b                         0.3095      0.405      0.764      0.447      -0.494       1.113
# measles                            -0.0822      0.090     -0.909      0.366      -0.262       0.097
# bmi                                -0.0043      0.016     -0.271      0.787      -0.036       0.027
# under-five_deaths                   2.9567      1.975      1.497      0.137      -0.961       6.874
# polio                               0.2570      0.492      0.522      0.603      -0.719       1.233
# total_expenditure                   0.4875      0.098      4.975      0.000       0.293       0.682
# diphtheria                         -0.4809      0.609     -0.790      0.432      -1.689       0.727
# hiv/aids                           -3.7634      0.666     -5.651      0.000      -5.084      -2.442
# gdp                                -0.1592      0.168     -0.950      0.344      -0.492       0.173
# population                         -0.0016      0.102     -0.015      0.988      -0.204       0.201
# thinness__1-19_years               -0.0141      0.159     -0.089      0.930      -0.330       0.302
# thinness_5-9_years                 -0.0020      0.161     -0.012      0.990      -0.321       0.317
# income_composition_of_resources    39.4133      5.374      7.334      0.000      28.752      50.074
# schooling                          -0.1951      0.222     -0.878      0.382      -0.636       0.246
# status_Developing                  -0.0966      0.791     -0.122      0.903      -1.666       1.473
# ==============================================================================
# Omnibus:                        0.446   Durbin-Watson:                   2.224
# Prob(Omnibus):                  0.800   Jarque-Bera (JB):                0.598
# Skew:                          -0.108   Prob(JB):                        0.741
# Kurtosis:                       2.730   Cond. No.                     5.29e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.29e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ================================================================================
#
# Removed Variable: hepatitis_b
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.921
# Method:                 Least Squares   F-statistic:                     77.72
# Date:                Thu, 05 Dec 2024   Prob (F-statistic):           8.02e-51
# Time:                        22:00:19   Log-Likelihood:                -252.67
# No. Observations:                 120   AIC:                             543.3
# Df Residuals:                     101   BIC:                             596.3
# Df Model:                          18
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              52.1725      3.215     16.225      0.000      45.794      58.551
# adult_mortality                    -0.0156      0.003     -4.730      0.000      -0.022      -0.009
# infant_deaths                      -2.5162      1.943     -1.295      0.198      -6.371       1.339
# alcohol                            -0.0424      0.072     -0.586      0.559      -0.186       0.101
# percentage_expenditure              1.1379      0.357      3.188      0.002       0.430       1.846
# measles                            -0.0663      0.086     -0.769      0.444      -0.238       0.105
# bmi                                 0.0005      0.015      0.031      0.976      -0.030       0.031
# under-five_deaths                   2.7717      1.889      1.468      0.145      -0.975       6.518
# polio                               0.1376      0.472      0.292      0.771      -0.798       1.074
# total_expenditure                   0.3904      0.099      3.952      0.000       0.194       0.586
# diphtheria                         -0.1420      0.472     -0.301      0.764      -1.079       0.794
# hiv/aids                           -3.5394      0.632     -5.602      0.000      -4.793      -2.286
# gdp                                -1.1716      0.352     -3.325      0.001      -1.871      -0.473
# population                         -0.0206      0.097     -0.212      0.833      -0.214       0.173
# thinness__1-19_years               -0.1634      0.158     -1.033      0.304      -0.477       0.150
# thinness_5-9_years                  0.1341      0.159      0.845      0.400      -0.181       0.449
# income_composition_of_resources    38.7435      4.976      7.786      0.000      28.872      48.615
# schooling                          -0.2319      0.201     -1.152      0.252      -0.631       0.167
# status_Developing                  -0.4380      0.738     -0.593      0.554      -1.902       1.026
# ==============================================================================
# Omnibus:                        0.889   Durbin-Watson:                   2.174
# Prob(Omnibus):                  0.641   Jarque-Bera (JB):                0.920
# Skew:                          -0.066   Prob(JB):                        0.631
# Kurtosis:                       2.592   Cond. No.                     5.24e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.24e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ================================================================================
#
# Removed Variable: measles
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     77.27
# Date:                Thu, 05 Dec 2024   Prob (F-statistic):           1.05e-50
# Time:                        22:00:19   Log-Likelihood:                -253.00
# No. Observations:                 120   AIC:                             544.0
# Df Residuals:                     101   BIC:                             597.0
# Df Model:                          18
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              52.2920      3.229     16.194      0.000      45.886      58.698
# adult_mortality                    -0.0157      0.003     -4.739      0.000      -0.022      -0.009
# infant_deaths                      -2.4778      1.948     -1.272      0.206      -6.343       1.387
# alcohol                            -0.0490      0.072     -0.679      0.499      -0.192       0.094
# percentage_expenditure              1.1366      0.363      3.134      0.002       0.417       1.856
# hepatitis_b                         0.0798      0.393      0.203      0.840      -0.700       0.859
# bmi                                 0.0016      0.015      0.104      0.917      -0.029       0.032
# under-five_deaths                   2.6352      1.887      1.397      0.166      -1.108       6.378
# polio                               0.1705      0.471      0.362      0.718      -0.764       1.105
# total_expenditure                   0.3973      0.099      4.029      0.000       0.202       0.593
# diphtheria                         -0.2782      0.587     -0.474      0.636      -1.442       0.886
# hiv/aids                           -3.5224      0.639     -5.512      0.000      -4.790      -2.255
# gdp                                -1.1579      0.360     -3.219      0.002      -1.871      -0.444
# population                         -0.0066      0.096     -0.069      0.946      -0.197       0.183
# thinness__1-19_years               -0.1658      0.159     -1.041      0.301      -0.482       0.150
# thinness_5-9_years                  0.1314      0.160      0.822      0.413      -0.186       0.448
# income_composition_of_resources    38.0396      5.142      7.397      0.000      27.839      48.241
# schooling                          -0.2348      0.211     -1.110      0.270      -0.654       0.185
# status_Developing                  -0.3304      0.761     -0.434      0.665      -1.839       1.178
# ==============================================================================
# Omnibus:                        0.785   Durbin-Watson:                   2.141
# Prob(Omnibus):                  0.675   Jarque-Bera (JB):                0.844
# Skew:                          -0.053   Prob(JB):                        0.656
# Kurtosis:                       2.603   Cond. No.                     5.32e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.32e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ================================================================================
#
# Removed Variable: bmi
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.921
# Method:                 Least Squares   F-statistic:                     77.77
# Date:                Thu, 05 Dec 2024   Prob (F-statistic):           7.75e-51
# Time:                        22:00:19   Log-Likelihood:                -252.63
# No. Observations:                 120   AIC:                             543.3
# Df Residuals:                     101   BIC:                             596.2
# Df Model:                          18
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              52.0794      3.209     16.227      0.000      45.713      58.446
# adult_mortality                    -0.0155      0.003     -4.705      0.000      -0.022      -0.009
# infant_deaths                      -2.5112      1.938     -1.296      0.198      -6.356       1.334
# alcohol                            -0.0428      0.072     -0.593      0.554      -0.186       0.100
# percentage_expenditure              1.1207      0.360      3.111      0.002       0.406       1.835
# hepatitis_b                         0.1045      0.393      0.266      0.791      -0.675       0.884
# measles                            -0.0684      0.086     -0.794      0.429      -0.239       0.102
# under-five_deaths                   2.7668      1.883      1.469      0.145      -0.970       6.503
# polio                               0.1363      0.471      0.289      0.773      -0.798       1.071
# total_expenditure                   0.3892      0.099      3.941      0.000       0.193       0.585
# diphtheria                         -0.2339      0.586     -0.399      0.691      -1.397       0.929
# hiv/aids                           -3.5685      0.634     -5.625      0.000      -4.827      -2.310
# gdp                                -1.1538      0.359     -3.217      0.002      -1.865      -0.442
# population                         -0.0229      0.097     -0.235      0.814      -0.216       0.170
# thinness__1-19_years               -0.1578      0.156     -1.009      0.316      -0.468       0.153
# thinness_5-9_years                  0.1289      0.151      0.851      0.397      -0.172       0.429
# income_composition_of_resources    38.4396      4.879      7.878      0.000      28.760      48.119
# schooling                          -0.2136      0.212     -1.005      0.317      -0.635       0.208
# status_Developing                  -0.3847      0.754     -0.510      0.611      -1.880       1.111
# ==============================================================================
# Omnibus:                        0.842   Durbin-Watson:                   2.166
# Prob(Omnibus):                  0.656   Jarque-Bera (JB):                0.892
# Skew:                          -0.070   Prob(JB):                        0.640
# Kurtosis:                       2.601   Cond. No.                     5.04e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.04e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ================================================================================
#
# Removed Variable: under-five_deaths
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.931
# Model:                            OLS   Adj. R-squared:                  0.919
# Method:                 Least Squares   F-statistic:                     76.04
# Date:                Thu, 05 Dec 2024   Prob (F-statistic):           2.21e-50
# Time:                        22:00:19   Log-Likelihood:                -253.89
# No. Observations:                 120   AIC:                             545.8
# Df Residuals:                     101   BIC:                             598.7
# Df Model:                          18
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              53.8603      3.026     17.800      0.000      47.858      59.863
# adult_mortality                    -0.0160      0.003     -4.811      0.000      -0.023      -0.009
# infant_deaths                       0.3123      0.251      1.246      0.216      -0.185       0.809
# alcohol                            -0.0352      0.073     -0.483      0.630      -0.180       0.109
# percentage_expenditure              1.1392      0.366      3.116      0.002       0.414       1.865
# hepatitis_b                         0.1143      0.397      0.288      0.774      -0.673       0.902
# measles                            -0.0573      0.087     -0.658      0.512      -0.230       0.116
# bmi                                 0.0020      0.015      0.130      0.897      -0.029       0.033
# polio                               0.1658      0.476      0.348      0.728      -0.779       1.111
# total_expenditure                   0.3849      0.100      3.853      0.000       0.187       0.583
# diphtheria                         -0.3146      0.591     -0.532      0.596      -1.487       0.858
# hiv/aids                           -3.3537      0.629     -5.328      0.000      -4.602      -2.105
# gdp                                -1.1462      0.362     -3.163      0.002      -1.865      -0.427
# population                         -0.0179      0.099     -0.181      0.857      -0.214       0.178
# thinness__1-19_years               -0.1408      0.160     -0.878      0.382      -0.459       0.177
# thinness_5-9_years                  0.1164      0.161      0.725      0.470      -0.202       0.435
# income_composition_of_resources    35.8287      4.890      7.327      0.000      26.129      45.528
# schooling                          -0.2056      0.215     -0.958      0.340      -0.631       0.220
# status_Developing                  -0.4933      0.766     -0.644      0.521      -2.014       1.027
# ==============================================================================
# Omnibus:                        0.117   Durbin-Watson:                   2.175
# Prob(Omnibus):                  0.943   Jarque-Bera (JB):                0.281
# Skew:                          -0.032   Prob(JB):                        0.869
# Kurtosis:                       2.772   Cond. No.                     4.83e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.83e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ================================================================================
#
# Removed Variable: polio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.921
# Method:                 Least Squares   F-statistic:                     77.71
# Date:                Thu, 05 Dec 2024   Prob (F-statistic):           8.06e-51
# Time:                        22:00:19   Log-Likelihood:                -252.68
# No. Observations:                 120   AIC:                             543.4
# Df Residuals:                     101   BIC:                             596.3
# Df Model:                          18
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              52.1063      3.230     16.131      0.000      45.698      58.514
# adult_mortality                    -0.0154      0.003     -4.694      0.000      -0.022      -0.009
# infant_deaths                      -2.5199      1.943     -1.297      0.198      -6.375       1.335
# alcohol                            -0.0430      0.072     -0.595      0.553      -0.186       0.100
# percentage_expenditure              1.1303      0.361      3.132      0.002       0.414       1.846
# hepatitis_b                         0.1063      0.393      0.271      0.787      -0.673       0.886
# measles                            -0.0705      0.086     -0.818      0.415      -0.241       0.100
# bmi                                 0.0007      0.015      0.044      0.965      -0.030       0.031
# under-five_deaths                   2.7868      1.887      1.477      0.143      -0.957       6.530
# total_expenditure                   0.3833      0.097      3.957      0.000       0.191       0.575
# diphtheria                         -0.1160      0.417     -0.278      0.781      -0.942       0.710
# hiv/aids                           -3.5620      0.640     -5.569      0.000      -4.831      -2.293
# gdp                                -1.1560      0.359     -3.222      0.002      -1.868      -0.444
# population                         -0.0221      0.098     -0.226      0.822      -0.216       0.172
# thinness__1-19_years               -0.1595      0.159     -1.002      0.319      -0.475       0.156
# thinness_5-9_years                  0.1307      0.159      0.820      0.414      -0.185       0.447
# income_composition_of_resources    38.2844      5.134      7.456      0.000      28.099      48.470
# schooling                          -0.2084      0.212     -0.984      0.327      -0.629       0.212
# status_Developing                  -0.4085      0.759     -0.538      0.591      -1.913       1.096
# ==============================================================================
# Omnibus:                        0.892   Durbin-Watson:                   2.156
# Prob(Omnibus):                  0.640   Jarque-Bera (JB):                0.930
# Skew:                          -0.076   Prob(JB):                        0.628
# Kurtosis:                       2.597   Cond. No.                     5.33e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.33e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ================================================================================
#
# Removed Variable: total_expenditure
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.922
# Model:                            OLS   Adj. R-squared:                  0.909
# Method:                 Least Squares   F-statistic:                     66.69
# Date:                Thu, 05 Dec 2024   Prob (F-statistic):           9.51e-48
# Time:                        22:00:19   Log-Likelihood:                -261.19
# No. Observations:                 120   AIC:                             560.4
# Df Residuals:                     101   BIC:                             613.3
# Df Model:                          18
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              56.8747      3.213     17.703      0.000      50.501      63.248
# adult_mortality                    -0.0169      0.004     -4.794      0.000      -0.024      -0.010
# infant_deaths                      -2.0808      2.083     -0.999      0.320      -6.213       2.052
# alcohol                             0.0066      0.076      0.086      0.931      -0.145       0.158
# percentage_expenditure              1.5795      0.368      4.290      0.000       0.849       2.310
# hepatitis_b                         0.1846      0.421      0.438      0.662      -0.651       1.020
# measles                            -0.1044      0.092     -1.130      0.261      -0.288       0.079
# bmi                                 0.0036      0.016      0.219      0.827      -0.029       0.036
# under-five_deaths                   2.5497      2.027      1.258      0.211      -1.471       6.570
# polio                              -0.2403      0.496     -0.484      0.629      -1.224       0.744
# diphtheria                         -0.0568      0.629     -0.090      0.928      -1.305       1.191
# hiv/aids                           -3.3798      0.685     -4.935      0.000      -4.739      -2.021
# gdp                                -1.4834      0.375     -3.961      0.000      -2.226      -0.740
# population                         -0.0916      0.103     -0.888      0.377      -0.296       0.113
# thinness__1-19_years               -0.1636      0.171     -0.957      0.341      -0.503       0.175
# thinness_5-9_years                  0.1147      0.171      0.671      0.504      -0.224       0.454
# income_composition_of_resources    35.4666      5.468      6.486      0.000      24.619      46.315
# schooling                          -0.1245      0.227     -0.549      0.584      -0.575       0.326
# status_Developing                  -0.9481      0.804     -1.180      0.241      -2.542       0.646
# ==============================================================================
# Omnibus:                        0.497   Durbin-Watson:                   2.149
# Prob(Omnibus):                  0.780   Jarque-Bera (JB):                0.567
# Skew:                          -0.148   Prob(JB):                        0.753
# Kurtosis:                       2.841   Cond. No.                     5.23e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.23e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ================================================================================
#
# Removed Variable: diphtheria
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.921
# Method:                 Least Squares   F-statistic:                     77.64
# Date:                Thu, 05 Dec 2024   Prob (F-statistic):           8.38e-51
# Time:                        22:00:19   Log-Likelihood:                -252.73
# No. Observations:                 120   AIC:                             543.5
# Df Residuals:                     101   BIC:                             596.4
# Df Model:                          18
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              52.0198      3.227     16.119      0.000      45.618      58.422
# adult_mortality                    -0.0155      0.003     -4.689      0.000      -0.022      -0.009
# infant_deaths                      -2.5672      1.939     -1.324      0.188      -6.413       1.278
# alcohol                            -0.0422      0.072     -0.584      0.561      -0.186       0.101
# percentage_expenditure              1.1413      0.359      3.179      0.002       0.429       1.853
# hepatitis_b                         0.0108      0.316      0.034      0.973      -0.616       0.637
# measles                            -0.0714      0.086     -0.828      0.410      -0.242       0.100
# bmi                              3.026e-05      0.015      0.002      0.998      -0.030       0.030
# under-five_deaths                   2.8329      1.882      1.506      0.135      -0.899       6.565
# polio                               0.0024      0.335      0.007      0.994      -0.662       0.666
# total_expenditure                   0.3860      0.099      3.912      0.000       0.190       0.582
# hiv/aids                           -3.5377      0.636     -5.562      0.000      -4.800      -2.276
# gdp                                -1.1749      0.355     -3.310      0.001      -1.879      -0.471
# population                         -0.0211      0.098     -0.216      0.830      -0.215       0.173
# thinness__1-19_years               -0.1592      0.159     -0.999      0.320      -0.475       0.157
# thinness_5-9_years                  0.1307      0.159      0.820      0.414      -0.186       0.447
# income_composition_of_resources    38.8150      5.041      7.700      0.000      28.815      48.815
# schooling                          -0.2230      0.211     -1.055      0.294      -0.642       0.196
# status_Developing                  -0.4502      0.746     -0.603      0.548      -1.930       1.030
# ==============================================================================
# Omnibus:                        0.959   Durbin-Watson:                   2.163
# Prob(Omnibus):                  0.619   Jarque-Bera (JB):                0.965
# Skew:                          -0.068   Prob(JB):                        0.617
# Kurtosis:                       2.582   Cond. No.                     5.24e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.24e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ================================================================================
#
# Removed Variable: hiv/aids
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.912
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     58.15
# Date:                Thu, 05 Dec 2024   Prob (F-statistic):           5.00e-45
# Time:                        22:00:19   Log-Likelihood:                -268.73
# No. Observations:                 120   AIC:                             575.5
# Df Residuals:                     101   BIC:                             628.4
# Df Model:                          18
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              53.2113      3.686     14.436      0.000      45.899      60.523
# adult_mortality                    -0.0258      0.003     -8.239      0.000      -0.032      -0.020
# infant_deaths                      -0.1066      2.167     -0.049      0.961      -4.405       4.191
# alcohol                            -0.0068      0.082     -0.083      0.934      -0.170       0.156
# percentage_expenditure              1.3226      0.412      3.211      0.002       0.505       2.140
# hepatitis_b                        -0.2409      0.444     -0.543      0.588      -1.121       0.639
# measles                            -0.0262      0.099     -0.266      0.791      -0.222       0.169
# bmi                                 0.0113      0.017      0.650      0.517      -0.023       0.046
# under-five_deaths                   0.3719      2.103      0.177      0.860      -3.800       4.543
# polio                               0.0757      0.539      0.140      0.889      -0.994       1.146
# total_expenditure                   0.3482      0.113      3.088      0.003       0.124       0.572
# diphtheria                          0.1293      0.668      0.194      0.847      -1.195       1.454
# gdp                                -1.4623      0.405     -3.608      0.000      -2.266      -0.658
# population                         -0.0052      0.112     -0.046      0.963      -0.227       0.216
# thinness__1-19_years               -0.2822      0.180     -1.566      0.120      -0.640       0.075
# thinness_5-9_years                  0.2916      0.179      1.628      0.107      -0.064       0.647
# income_composition_of_resources    42.7860      5.816      7.357      0.000      31.249      54.323
# schooling                          -0.4408      0.239     -1.848      0.068      -0.914       0.032
# status_Developing                  -0.3689      0.871     -0.423      0.673      -2.097       1.359
# ==============================================================================
# Omnibus:                        0.529   Durbin-Watson:                   2.154
# Prob(Omnibus):                  0.768   Jarque-Bera (JB):                0.653
# Skew:                          -0.012   Prob(JB):                        0.722
# Kurtosis:                       2.639   Cond. No.                     5.32e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.32e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ================================================================================
#
# Removed Variable: gdp
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.926
# Model:                            OLS   Adj. R-squared:                  0.913
# Method:                 Least Squares   F-statistic:                     70.03
# Date:                Thu, 05 Dec 2024   Prob (F-statistic):           1.01e-48
# Time:                        22:00:19   Log-Likelihood:                -258.48
# No. Observations:                 120   AIC:                             555.0
# Df Residuals:                     101   BIC:                             607.9
# Df Model:                          18
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              48.8761      3.225     15.158      0.000      42.479      55.273
# ...
# Skew:                          -0.116   Prob(JB):                        0.608
# Kurtosis:                       2.619   Cond. No.                     5.33e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.33e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ================================================================================
#
# Removed Variable: thinness_5-9_years
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     77.23
# Date:                Thu, 05 Dec 2024   Prob (F-statistic):           1.08e-50
# Time:                        22:00:19   Log-Likelihood:                -253.03
# No. Observations:                 120   AIC:                             544.1
# Df Residuals:                     101   BIC:                             597.0
# Df Model:                          18
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              52.0509      3.240     16.066      0.000      45.624      58.478
# adult_mortality                    -0.0151      0.003     -4.614      0.000      -0.022      -0.009
# infant_deaths                      -2.4099      1.946     -1.239      0.218      -6.269       1.450
# alcohol                            -0.0401      0.072     -0.553      0.581      -0.184       0.104
# percentage_expenditure              1.0423      0.350      2.979      0.004       0.348       1.736
# hepatitis_b                         0.1331      0.393      0.339      0.735      -0.646       0.912
# measles                            -0.0687      0.087     -0.792      0.430      -0.241       0.103
# bmi                                -0.0034      0.015     -0.235      0.815      -0.033       0.026
# under-five_deaths                   2.6708      1.891      1.412      0.161      -1.081       6.422
# polio                               0.1382      0.473      0.292      0.771      -0.801       1.077
# total_expenditure                   0.3870      0.099      3.902      0.000       0.190       0.584
# diphtheria                         -0.2377      0.589     -0.403      0.688      -1.407       0.931
# hiv/aids                           -3.6612      0.631     -5.802      0.000      -4.913      -2.409
# gdp                                -1.0915      0.352     -3.104      0.002      -1.789      -0.394
# population                         -0.0328      0.097     -0.338      0.736      -0.226       0.160
# thinness__1-19_years               -0.0379      0.060     -0.632      0.529      -0.157       0.081
# income_composition_of_resources    38.5035      5.161      7.460      0.000      28.265      48.743
# schooling                          -0.2009      0.213     -0.945      0.347      -0.623       0.221
# status_Developing                  -0.3475      0.763     -0.456      0.650      -1.860       1.166
# ==============================================================================
# Omnibus:                        1.040   Durbin-Watson:                   2.158
# Prob(Omnibus):                  0.595   Jarque-Bera (JB):                1.058
# Skew:                          -0.107   Prob(JB):                        0.589
# Kurtosis:                       2.593   Cond. No.                     5.34e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.34e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ================================================================================
#
# Removed Variable: income_composition_of_resources
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.896
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     48.15
# Date:                Thu, 05 Dec 2024   Prob (F-statistic):           2.39e-41
# Time:                        22:00:19   Log-Likelihood:                -278.97
# No. Observations:                 120   AIC:                             595.9
# Df Residuals:                     101   BIC:                             648.9
# Df Model:                          18
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     63.1505      3.573     17.674      0.000      56.062      70.239
# adult_mortality           -0.0200      0.004     -4.940      0.000      -0.028      -0.012
# infant_deaths              2.4307      2.275      1.069      0.288      -2.082       6.943
# alcohol                    0.0554      0.089      0.626      0.532      -0.120       0.231
# percentage_expenditure     1.2945      0.450      2.877      0.005       0.402       2.187
# hepatitis_b                0.8552      0.473      1.808      0.074      -0.083       1.793
# measles                   -0.0119      0.107     -0.111      0.912      -0.225       0.201
# bmi                        0.0369      0.018      2.032      0.045       0.001       0.073
# under-five_deaths         -2.0340      2.211     -0.920      0.360      -6.420       2.352
# polio                     -0.1234      0.586     -0.211      0.834      -1.286       1.039
# total_expenditure          0.2824      0.122      2.318      0.022       0.041       0.524
# diphtheria                -1.1330      0.716     -1.582      0.117      -2.554       0.288
# hiv/aids                  -4.2966      0.787     -5.459      0.000      -5.858      -2.735
# gdp                       -0.7967      0.443     -1.800      0.075      -1.675       0.081
# population                -0.0931      0.121     -0.769      0.444      -0.333       0.147
# thinness__1-19_years      -0.1940      0.198     -0.979      0.330      -0.587       0.199
# thinness_5-9_years         0.1615      0.198      0.814      0.417      -0.232       0.555
# schooling                  0.8501      0.196      4.332      0.000       0.461       1.239
# status_Developing         -1.0115      0.943     -1.073      0.286      -2.882       0.859
# ==============================================================================
# Omnibus:                        4.155   Durbin-Watson:                   2.076
# Prob(Omnibus):                  0.125   Jarque-Bera (JB):                3.565
# Skew:                          -0.387   Prob(JB):                        0.168
# Kurtosis:                       3.337   Cond. No.                     2.98e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.98e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ================================================================================
#
# Removed Variable: schooling
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     76.95
# Date:                Thu, 05 Dec 2024   Prob (F-statistic):           1.27e-50
# Time:                        22:00:19   Log-Likelihood:                -253.23
# No. Observations:                 120   AIC:                             544.5
# Df Residuals:                     101   BIC:                             597.4
# Df Model:                          18
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              51.8011      3.233     16.024      0.000      45.388      58.214
# adult_mortality                    -0.0155      0.003     -4.654      0.000      -0.022      -0.009
# infant_deaths                      -2.4053      1.950     -1.234      0.220      -6.273       1.463
# alcohol                            -0.0401      0.073     -0.552      0.582      -0.184       0.104
# percentage_expenditure              1.1114      0.364      3.056      0.003       0.390       1.833
# hepatitis_b                         0.2318      0.374      0.620      0.537      -0.510       0.973
# measles                            -0.0791      0.086     -0.917      0.361      -0.250       0.092
# bmi                                 0.0001      0.015      0.007      0.994      -0.031       0.031
# under-five_deaths                   2.7134      1.897      1.430      0.156      -1.050       6.476
# polio                               0.0945      0.472      0.200      0.842      -0.842       1.031
# total_expenditure                   0.3784      0.099      3.830      0.000       0.182       0.574
# diphtheria                         -0.2999      0.587     -0.511      0.610      -1.464       0.864
# hiv/aids                           -3.6895      0.631     -5.849      0.000      -4.941      -2.438
# gdp                                -1.1314      0.360     -3.145      0.002      -1.845      -0.418
# population                         -0.0450      0.096     -0.471      0.638      -0.235       0.145
# thinness__1-19_years               -0.1441      0.159     -0.904      0.368      -0.460       0.172
# thinness_5-9_years                  0.1185      0.160      0.742      0.460      -0.198       0.435
# income_composition_of_resources    34.9203      3.835      9.107      0.000      27.313      42.527
# status_Developing                  -0.2951      0.760     -0.388      0.699      -1.803       1.212
# ==============================================================================
# Omnibus:                        0.645   Durbin-Watson:                   2.152
# Prob(Omnibus):                  0.724   Jarque-Bera (JB):                0.769
# Skew:                          -0.094   Prob(JB):                        0.681
# Kurtosis:                       2.655   Cond. No.                     4.63e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.63e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ================================================================================
#
# Removed Variable: status_Developing
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.921
# Method:                 Least Squares   F-statistic:                     77.56
# Date:                Thu, 05 Dec 2024   Prob (F-statistic):           8.80e-51
# Time:                        22:00:19   Log-Likelihood:                -252.78
# No. Observations:                 120   AIC:                             543.6
# Df Residuals:                     101   BIC:                             596.5
# Df Model:                          18
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              51.3781      2.915     17.625      0.000      45.595      57.161
# adult_mortality                    -0.0155      0.003     -4.695      0.000      -0.022      -0.009
# infant_deaths                      -2.6216      1.932     -1.357      0.178      -6.455       1.212
# alcohol                            -0.0373      0.072     -0.522      0.603      -0.179       0.105
# percentage_expenditure              1.0990      0.360      3.055      0.003       0.385       1.813
# hepatitis_b                         0.1540      0.381      0.404      0.687      -0.602       0.910
# measles                            -0.0640      0.086     -0.742      0.460      -0.235       0.107
# bmi                                -0.0007      0.015     -0.045      0.964      -0.031       0.030
# under-five_deaths                   2.8539      1.882      1.516      0.133      -0.880       6.587
# polio                               0.1583      0.470      0.337      0.737      -0.775       1.091
# total_expenditure                   0.3985      0.097      4.097      0.000       0.206       0.591
# diphtheria                         -0.2963      0.576     -0.515      0.608      -1.438       0.846
# hiv/aids                           -3.5648      0.640     -5.567      0.000      -4.835      -2.294
# gdp                                -1.1459      0.359     -3.194      0.002      -1.858      -0.434
# population                         -0.0199      0.098     -0.204      0.839      -0.214       0.174
# thinness__1-19_years               -0.1542      0.159     -0.969      0.335      -0.470       0.161
# thinness_5-9_years                  0.1251      0.159      0.786      0.434      -0.191       0.441
# income_composition_of_resources    38.6806      5.122      7.552      0.000      28.521      48.841
# schooling                          -0.2006      0.211     -0.950      0.344      -0.620       0.218
# ==============================================================================
# Omnibus:                        0.617   Durbin-Watson:                   2.160
# Prob(Omnibus):                  0.735   Jarque-Bera (JB):                0.735
# Skew:                          -0.070   Prob(JB):                        0.693
# Kurtosis:                       2.643   Cond. No.                     5.24e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.24e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ================================================================================

# %% [markdown]
# ##### Neither measles nor population are significant in any of the above models, so remove both of these variables from the final model

# %% [markdown]
# ### Other Considerations: Redundant Variables
# ##### Some variables such as under-five_deaths, infant_deaths, thinness__1-19_years, and thinness_5-9_years are redundant.
# This is because under-five deaths includes infant deaths and thinness 1-19 years includes thinness 5-9 years. Therefore, to reduce redundancy and streamline our final set of variables, we decided to keep only the broader variable and remove infant deaths and thinness 5-9 years.

# %%
# drop measles and population
X_final = X_cleaned.drop(columns = ["measles", "population", "infant_deaths", "thinness_5-9_years"])
X_final = sm.add_constant(X_final)  # Add constant for intercept

# Fit the final model
final_model = sm.OLS(y_cleaned, X_final).fit()

# Display the summary
print(final_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.931
# Model:                            OLS   Adj. R-squared:                  0.921
# Method:                 Least Squares   F-statistic:                     93.27
# Date:                Thu, 05 Dec 2024   Prob (F-statistic):           3.64e-53
# Time:                        23:03:54   Log-Likelihood:                -254.30
# No. Observations:                 120   AIC:                             540.6
# Df Residuals:                     104   BIC:                             585.2
# Df Model:                          15
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              53.5446      2.741     19.538      0.000      48.110      58.979
# adult_mortality                    -0.0157      0.003     -4.853      0.000      -0.022      -0.009
# alcohol                            -0.0431      0.069     -0.629      0.531      -0.179       0.093
# percentage_expenditure              1.0861      0.344      3.156      0.002       0.404       1.769
# hepatitis_b                         0.1104      0.389      0.284      0.777      -0.661       0.882
# bmi                                -0.0006      0.014     -0.041      0.967      -0.029       0.028
# under-five_deaths                   0.2288      0.178      1.286      0.201      -0.124       0.581
# polio                               0.1810      0.469      0.386      0.700      -0.749       1.111
# total_expenditure                   0.3918      0.097      4.047      0.000       0.200       0.584
# diphtheria                         -0.3278      0.582     -0.563      0.574      -1.481       0.826
# hiv/aids                           -3.4363      0.608     -5.648      0.000      -4.643      -2.230
# gdp                                -1.1005      0.348     -3.160      0.002      -1.791      -0.410
# thinness__1-19_years               -0.0411      0.059     -0.695      0.488      -0.158       0.076
# income_composition_of_resources    36.1147      4.777      7.560      0.000      26.642      45.588
# schooling                          -0.2178      0.206     -1.059      0.292      -0.626       0.190
# status_Developing                  -0.3963      0.750     -0.528      0.598      -1.883       1.091
# ==============================================================================
# Omnibus:                        0.247   Durbin-Watson:                   2.140
# Prob(Omnibus):                  0.884   Jarque-Bera (JB):                0.418
# Skew:                          -0.052   Prob(JB):                        0.811
# Kurtosis:                       2.731   Cond. No.                     4.71e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.71e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
rss = final_model.ssr
df_residuals = final_model.df_resid
rse = np.sqrt(rss / df_residuals)
print(f"Standard Error of the Model (RSE): {rse}")
# Out:
# Standard Error of the Model (RSE): 2.1636497164205726

# %% [markdown]
# # 8. Validate that your residuals adhere to the regression assumptions as described in step 6.

# %%
sns.residplot(x=final_model.fittedvalues, y=final_model.resid, lowess=True, line_kws={"color": "red"})
plt.title("Residuals vs. Fitted Values")
plt.xlabel("Fitted Values")
plt.ylabel("Residuals")
plt.show()

# %%
sm.qqplot(final_model.resid, line='45')
plt.title("Q-Q Plot of Residuals")
plt.show()

# %%
# histogram of residuals

sns.histplot(final_model.resid, kde=True)
plt.title("Histogram of Residuals")
plt.show()

# %%
bp_test = het_breuschpagan(final_model.resid, final_model.model.exog)
print(f"Breusch-Pagan Test Statistic: {bp_test[0]}, p-value: {bp_test[1]}")

if bp_test[1] < 0.05:
    print("Evidence of heteroscedasticity. Consider transformations.")
else:
    print("No evidence of heteroscedasticity.")
# Out:
# Breusch-Pagan Test Statistic: 11.525749190037825, p-value: 0.7145130233955219
# No evidence of heteroscedasticity.

# %%
# Studentized Residuals

influence = final_model.get_influence()
studentized_residuals = influence.resid_studentized_internal
sns.histplot(studentized_residuals, kde=True)
plt.title("Histogram of Studentized Residuals")
plt.show()

# %%
# Calculate studentized residuals
influence = OLSInfluence(final_model)
studentized_residuals = influence.resid_studentized_internal

# Flag outliers
outliers = studentized_residuals[abs(studentized_residuals) > 2].index
extreme_outliers = studentized_residuals[abs(studentized_residuals) > 3].index

print("Potential Outliers (|residuals| > 2):", outliers.tolist())
print("Extreme Outliers (|residuals| > 3):", extreme_outliers.tolist())
# Out:
# Potential Outliers (|residuals| > 2): [1, 289, 899, 995, 1347, 2698]
# Extreme Outliers (|residuals| > 3): []

# %%
# Leverage points

# Calculate leverage
leverage = influence.hat_matrix_diag
k = final_model.df_model  # Number of predictors
n = final_model.nobs  # Number of observations
leverage_threshold = 3 * (k + 1) / n

# Identify high-leverage points
high_leverage_points = (leverage > leverage_threshold).nonzero()[0]

print("High-Leverage Points (leverage > {:.3f}):".format(leverage_threshold), high_leverage_points)
# Out:
# High-Leverage Points (leverage > 0.400): [60 69]

# %%
sns.scatterplot(x=leverage, y=studentized_residuals)
plt.axhline(y=2, color='red', linestyle='--', label="Residual Threshold ±2")
plt.axhline(y=-2, color='red', linestyle='--')
plt.axvline(x=leverage_threshold, color='blue', linestyle='--', label="Leverage Threshold")
plt.title("Leverage vs. Studentized Residuals")
plt.legend()
plt.show()

# %%
# Cook's D

# Calculate Cook's Distance
cooks_d = influence.cooks_distance[0]
cooks_threshold = 4 / n

# Identify influential points
influential_points = cooks_d[cooks_d > cooks_threshold].index

print("Influential Points (Cook's Distance > {:.3f}):".format(cooks_threshold), influential_points.tolist())
# Out:
# Influential Points (Cook's Distance > 0.033): [1, 289, 899, 995, 1347, 1523, 1830, 2120, 2394, 2698]

# %%
sns.scatterplot(x=range(len(cooks_d)), y=cooks_d)
plt.axhline(y=cooks_threshold, color='red', linestyle='--', label="Cook's Threshold")
plt.title("Cook's Distance")
plt.legend()
plt.show()

# %% [markdown]
# ### Calculate Economic Significance

# %%
# Extract coefficients from the model
coefficients = final_model.params
std_errors = final_model.bse

# Extract standard deviations for continuous variables from the dataset
std_devs = X_final.std()  # Replace 'data_cleaned' with your cleaned dataset

# Initialize an empty DataFrame to store results
economic_significance_df = pd.DataFrame(columns=["Variable", "Coefficient", "Std_Dev", "Economic_Significance"])

# Process each variable
for variable in X_final.columns:
    if variable != "const":
        coef = coefficients[variable]
        if variable in std_devs:  # continuous variable
            std_dev = std_devs[variable]
            econ_significance = abs(coef) * std_dev
        else: # categ. var
            econ_significance = abs(coef)

        economic_significance_df = economic_significance_df.append(
            {
                "Variable": variable,
                "Coefficient": coef,
                "Std_Dev": std_devs.get(variable, "N/A"),  # N/A for categorical variables
                "Economic_Significance": econ_significance,
            },
            ignore_index=True,
        )

# sort and display results
economic_significance_df = economic_significance_df.sort_values(by="Economic_Significance", ascending=False)
print(economic_significance_df)

plt.figure(figsize=(10, 6))
plt.barh(economic_significance_df["Variable"], economic_significance_df["Economic_Significance"], color='skyblue')
plt.xlabel("Economic Significance")
plt.ylabel("Variables")
plt.title("Economic Significance of Variables")
plt.gca().invert_yaxis()
plt.show()
# Out:
# C:\Users\Lily Sun\AppData\Local\Temp\ipykernel_25108\382474117.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   economic_significance_df = economic_significance_df.append(
# C:\Users\Lily Sun\AppData\Local\Temp\ipykernel_25108\382474117.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   economic_significance_df = economic_significance_df.append(
# C:\Users\Lily Sun\AppData\Local\Temp\ipykernel_25108\382474117.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   economic_significance_df = economic_significance_df.append(
# C:\Users\Lily Sun\AppData\Local\Temp\ipykernel_25108\382474117.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   economic_significance_df = economic_significance_df.append(
# C:\Users\Lily Sun\AppData\Local\Temp\ipykernel_25108\382474117.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   economic_significance_df = economic_significance_df.append(
# C:\Users\Lily Sun\AppData\Local\Temp\ipykernel_25108\382474117.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   economic_significance_df = economic_significance_df.append(
# C:\Users\Lily Sun\AppData\Local\Temp\ipykernel_25108\382474117.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   economic_significance_df = economic_significance_df.append(
# C:\Users\Lily Sun\AppData\Local\Temp\ipykernel_25108\382474117.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   economic_significance_df = economic_significance_df.append(
# C:\Users\Lily Sun\AppData\Local\Temp\ipykernel_25108\382474117.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   economic_significance_df = economic_significance_df.append(
# C:\Users\Lily Sun\AppData\Local\Temp\ipykernel_25108\382474117.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   economic_significance_df = economic_significance_df.append(
# C:\Users\Lily Sun\AppData\Local\Temp\ipykernel_25108\382474117.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   economic_significance_df = economic_significance_df.append(
# C:\Users\Lily Sun\AppData\Local\Temp\ipykernel_25108\382474117.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   economic_significance_df = economic_significance_df.append(
# C:\Users\Lily Sun\AppData\Local\Temp\ipykernel_25108\382474117.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   economic_significance_df = economic_significance_df.append(
# C:\Users\Lily Sun\AppData\Local\Temp\ipykernel_25108\382474117.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   economic_significance_df = economic_significance_df.append(
# C:\Users\Lily Sun\AppData\Local\Temp\ipykernel_25108\382474117.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   economic_significance_df = economic_significance_df.append(
#                            Variable  Coefficient     Std_Dev  \
# 12  income_composition_of_resources    36.114658    0.147746
# 2            percentage_expenditure     1.086090    1.917406
# 10                              gdp    -1.100463    1.815899
# 9                          hiv/aids    -3.436317    0.509306
# 0                   adult_mortality    -0.015736  102.966618
# 7                 total_expenditure     0.391834    2.453161
# 13                        schooling    -0.217788    2.620549
# 8                        diphtheria    -0.327751    1.185551
# 5                 under-five_deaths     0.228761    1.691768
# 6                             polio     0.180988    1.209793
# 11             thinness__1-19_years    -0.041055    4.514283
# 1                           alcohol    -0.043139    3.991336
# 14                status_Developing    -0.396256    0.350170
# 3                       hepatitis_b     0.110395    1.185373
# 4                               bmi    -0.000598   20.667500
#
#     Economic_Significance
# 12               5.335807
# 2                2.082475
# 10               1.998329
# 9                1.750138
# 0                1.620249
# 7                0.961232
# 13               0.570724
# 8                0.388565
# 5                0.387011
# 6                0.218958
# 11               0.185333
# 1                0.172181
# 14               0.138757
# 3                0.130860
# 4                0.012363
